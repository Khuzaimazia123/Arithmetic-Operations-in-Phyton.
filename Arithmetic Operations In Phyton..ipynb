# %%
#Arithmetic Operations in Phyton.

#Addition

V=568

G=67

result=V + G
print (result)

#Subtraction

T=480

H=321

answer=T - H
print (answer)

#Multiplication

F=4

J=6

Result= F * J
print (Result)

#Division

E=51

I=3

Answer= 51/3
print (Answer)

#Floor Division

O=366

P=7

answer=O//L
print (answer)

#Modulus

R=483

S=2

Result=R%S
print (Result)

#Exponentation

U=6

T=3
Answer=U**T
print (Answer)
# Out:
# 635
# 159
# 24
# 17.0
# 6
# 1
# 216
